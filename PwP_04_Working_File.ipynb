# %% [markdown]
# #  Practice with Professor (Session 4)
# ## Assignment_03_Solution

# %% [markdown]
# ## Part A] State-wise cigarette consumption

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Average by state across all years into a data frame

# %%
# List column names

#index-method returns the position at the first occurrence of the specified value.

# %%
# List column names

# %%
# Make new column names

# %%
# Sort

# %%
# Join

# %%
# Plot

# %% [markdown]
# ## Part B] COVID-19 Study: Visualization using Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#subset the dataset


#print some rows

# %%
from datetime import datetime
#change the date column from object to date type
#print the new types

# %% [markdown]
# ### Case Study: IPL (Indian Premier League) - Player Auction Cost
# ![P1.jpg](attachment:P1.jpg)

# %% [markdown]
# ## Explore the variables
# ![P2.jpg](attachment:P2.jpg)

# %%
#Task 1: Read the 'IPL Data.csv'
import pandas as pd
ipl_auction_df = pd.read_csv( 'IPL Data.csv' )

# %%
# Task 2: Exploratory data analysis
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
# Task 3: Display first five rows and first 10 columns
ipl_auction_df.iloc[0:5, 0:10]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B
# 0           0      0.00
# 1         657     71.41
# 2        1269     80.62
# 3         241     84.56
# 4          79     45.93

# %%
# Task 4: Display first five rows and 13th columns onwards
ipl_auction_df.iloc[0:5, 13:]
# Out:
#    RUNS-S  HS    AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  \
# 0       0   0   0.00    0.00       0     307    15   20.47   8.90  13.93
# 1       0   0   0.00    0.00       0      29     0    0.00  14.50   0.00
# 2     167  39  18.56  121.01       5    1059    29   36.52   8.81  24.90
# 3      58  11   5.80   76.32       0    1125    49   22.96   6.23  22.14
# 4    1317  71  32.93  120.71      28       0     0    0.00   0.00   0.00
#
#    AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0          2009       50000       50000
# 1          2008       50000       50000
# 2          2008      200000      350000
# 3          2011      100000      850000
# 4          2011      100000      800000

# %%
# Task 5: Check for null values
ipl_auction_df.isnull().sum()
# Out:
# Sl.NO.           0
# PLAYER NAME      0
# AGE              0
# COUNTRY          0
# TEAM             0
# PLAYING ROLE     0
# T-RUNS           0
# T-WKTS           0
# ODI-RUNS-S       0
# ODI-SR-B         0
# ODI-WKTS         0
# ODI-SR-BL        0
# CAPTAINCY EXP    0
# RUNS-S           0
# HS               0
# AVE              0
# SR-B             0
# SIXERS           0
# RUNS-C           0
# WKTS             0
# AVE-BL           0
# ECON             0
# SR-BL            0
# AUCTION YEAR     0
# BASE PRICE       0
# SOLD PRICE       0
# dtype: int64

# %%
# Task 6:  Assign all independent variables to object
X_features = ipl_auction_df.columns

# %%
X_features = ['AGE', 'COUNTRY', 'PLAYING ROLE',
'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B',
'ODI-WKTS', 'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S',
'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS',
'AVE-BL', 'ECON', 'SR-BL']

# %% [markdown]
# + Sl.NO., PLAYER NAME, TEAM, BASE PRICE didnt considered

# %% [markdown]
# ### Task 7: Encoding Categorical Features

# %%
ipl_auction_df['PLAYING ROLE'].unique()
# Out:
# array(['Allrounder', 'Bowler', 'Batsman', 'W. Keeper'], dtype=object)

# %%
pd.get_dummies(ipl_auction_df['PLAYING ROLE'])[0:5]
# Out:
#    Allrounder  Batsman  Bowler  W. Keeper
# 0           1        0       0          0
# 1           0        0       1          0
# 2           0        0       1          0
# 3           0        0       1          0
# 4           0        1       0          0

# %%
categorical_features = ['AGE', 'COUNTRY', 'PLAYING ROLE', 'CAPTAINCY EXP']

# %%
ipl_auction_encoded_df = pd.get_dummies( ipl_auction_df[X_features],
columns = categorical_features,
drop_first = True)

# %% [markdown]
# + drop_first=True is important to use, as it helps in reducing the extra column created during dummy variable creation. Hence it reduces the correlations created among dummy variables
# + I think it depends on the model. If you don't drop the first column then your dummy variables will be correlated (redundant as Dimitre shows in the post below). This may affect some models adversely and the effect is stronger when the cardinality is smaller. For example iterative models may have trouble converging and lists of variable importances may be distorted.
# + If you have a small number of dummies, i suggest removing the first dummy. For example, if you have a variable gender, you don't need both a male and female dummy. Just one will be fine. If male=1 then the person is a male and if male=0 then the person is female. However if you have a category with hundreds of values, I suggest not dropping the first column. That will make it easier for the model to "see" all the categories quickly during learning (and the adverse effects are negligible).

# %%
X_features = ipl_auction_encoded_df.columns # all independent varaibles 
X_features
# Out:
# Index(['T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL',
#        'ECON', 'SR-BL', 'AGE_2', 'AGE_3', 'COUNTRY_BAN', 'COUNTRY_ENG',
#        'COUNTRY_IND', 'COUNTRY_NZ', 'COUNTRY_PAK', 'COUNTRY_SA', 'COUNTRY_SL',
#        'COUNTRY_WI', 'COUNTRY_ZIM', 'PLAYING ROLE_Batsman',
#        'PLAYING ROLE_Bowler', 'PLAYING ROLE_W. Keeper', 'CAPTAINCY EXP_1'],
#       dtype='object')

# %%
# Task 8: Add constant (intercept) and assign dependent variable "Sold Price"
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
X = sm.add_constant( ipl_auction_encoded_df )
Y = ipl_auction_df['SOLD PRICE']
train_X, test_X, train_y, test_y = train_test_split( X ,Y,train_size = 0.8,random_state = 40 )

# %% [markdown]
# ## Task 9: Building the model on training dataset

# %%
ipl_model_1 = sm.OLS(train_y, train_X).fit()
print(ipl_model_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             SOLD PRICE   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     3.424
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):           8.80e-06
# Time:                        17:17:20   Log-Likelihood:                -1441.9
# No. Observations:                 104   AIC:                             2948.
# Df Residuals:                      72   BIC:                             3032.
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   3.704e+05   2.06e+05      1.797      0.076   -4.04e+04    7.81e+05
# ...

# %% [markdown]
# ## Detecting Multicollinearity Using Variance Inflation Factors (VIF)

# %% [markdown]
# + Multicollinearity occurs when there are two or more independent variables in a multiple regression model, which have a high correlation among themselves.
# + When some features are highly correlated, we might have difficulty in distinguishing between their individual effects on the dependent variable.
# + Multicollinearity can be detected using various techniques, one such technique being the **Variance Inflation Factor(VIF).**
# ![P4.jpg](attachment:P4.jpg)
# + VIF is 4, with higher values

# %%
# Task 10: Detecting Multicollinearity Using Variance Inflation Factors
from statsmodels.stats.outliers_influence import variance_inflation_factor
def get_vif_factors( X ):
    X_matrix = X.to_numpy()
    vif = [ variance_inflation_factor( X_matrix, i ) for i in range( X_matrix.shape[1] ) ]
    vif_factors = pd.DataFrame()
    vif_factors['column'] = X.columns
    vif_factors['vif'] = vif
    return vif_factors

# %%
vif_factors = get_vif_factors( X[X_features])
vif_factors
# Out:
#                     column         vif
# 0                   T-RUNS   12.612694
# 1                   T-WKTS    7.679284
# 2               ODI-RUNS-S   16.426209
# 3                 ODI-SR-B   13.829376
# 4                 ODI-WKTS    9.951800
# 5                ODI-SR-BL    4.426818
# 6                   RUNS-S   16.135407
# 7                       HS   22.781017
# 8                      AVE   25.226566
# 9                     SR-B   21.576204
# 10                  SIXERS    9.547268
# 11                  RUNS-C   38.229691
# 12                    WKTS   33.366067
# 13                  AVE-BL  100.198105
# 14                    ECON    7.650140
# 15                   SR-BL  103.723846
# 16                   AGE_2    6.996226
# 17                   AGE_3    3.855003
# 18             COUNTRY_BAN    1.469017
# 19             COUNTRY_ENG    1.391524
# 20             COUNTRY_IND    4.568898
# 21              COUNTRY_NZ    1.497856
# 22             COUNTRY_PAK    1.796355
# ...

# %%
columns_with_large_vif = vif_factors[vif_factors.vif > 4].column
columns_with_large_vif
# Out:
# 0                   T-RUNS
# 1                   T-WKTS
# 2               ODI-RUNS-S
# 3                 ODI-SR-B
# 4                 ODI-WKTS
# 5                ODI-SR-BL
# 6                   RUNS-S
# 7                       HS
# 8                      AVE
# 9                     SR-B
# 10                  SIXERS
# 11                  RUNS-C
# 12                    WKTS
# 13                  AVE-BL
# 14                    ECON
# 15                   SR-BL
# 16                   AGE_2
# 20             COUNTRY_IND
# 27    PLAYING ROLE_Batsman
# 30         CAPTAINCY EXP_1
# Name: column, dtype: object

# %%
columns_to_be_removed = ['T-RUNS', 'T-WKTS', 'RUNS-S', 'HS',
'AVE', 'RUNS-C', 'SR-B', 'AVE-BL',
'ECON', 'ODI-SR-B', 'ODI-RUNS-S', 'AGE_2', 'SR-BL']

# %%
X_new_features = list( set(X_features) - set(columns_to_be_removed) )

# %%
get_vif_factors( X[X_new_features] )
# Out:
#                     column       vif
# 0          CAPTAINCY EXP_1  2.458745
# 1               COUNTRY_SL  1.519752
# 2              COUNTRY_ZIM  1.205305
# 3      PLAYING ROLE_Bowler  3.060168
# 4   PLAYING ROLE_W. Keeper  1.900941
# 5              COUNTRY_IND  3.144668
# 6                     WKTS  2.883101
# 7              COUNTRY_ENG  1.131869
# 8                ODI-SR-BL  2.822148
# 9               COUNTRY_NZ  1.173418
# 10                  SIXERS  2.397409
# 11    PLAYING ROLE_Batsman  2.680207
# 12                   AGE_3  1.779861
# 13              COUNTRY_WI  1.194093
# 14              COUNTRY_SA  1.416657
# 15                ODI-WKTS  2.742889
# 16             COUNTRY_BAN  1.094293
# 17             COUNTRY_PAK  1.334773

# %% [markdown]
# # Task 11: Building a new model after removing multicollinearity

# %%
train_X = train_X[X_new_features]
ipl_model_2 = sm.OLS(train_y, train_X).fit()
print(ipl_model_2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:             SOLD PRICE   R-squared (uncentered):                   0.785
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              17.48
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):                    1.77e-21
# Time:                        17:17:20   Log-Likelihood:                         -1458.7
# No. Observations:                 104   AIC:                                      2953.
# Df Residuals:                      86   BIC:                                      3001.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
significant_vars = ['COUNTRY_IND', 'COUNTRY_ENG', 'SIXERS', 'CAPTAINCY EXP_1','ODI-WKTS','SIXERS']
train_X = train_X[significant_vars]
ipl_model_3 = sm.OLS(train_y, train_X).fit()
print(ipl_model_3.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:             SOLD PRICE   R-squared (uncentered):                   0.744
# Model:                            OLS   Adj. R-squared (uncentered):              0.731
# Method:                 Least Squares   F-statistic:                              57.52
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):                    9.12e-28
# Time:                        17:17:20   Log-Likelihood:                         -1467.9
# No. Observations:                 104   AIC:                                      2946.
# Df Residuals:                      99   BIC:                                      2959.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Residual Analysis
# ### P-P Plot
# #### Test the assumpation that error follows normal distribution

# %%
import seaborn as sn
# %matplotlib inline
def draw_pp_plot( model, title ):
    probplot = sm.ProbPlot( model.resid, fit = True );
    probplot.ppplot( line='45' ); #45-degree line.

# %%
draw_pp_plot(ipl_model_3,"Figure - Normal P-P Plot of Regression Standardized Residuals");

# %% [markdown]
# + A residual is the difference between an observed value and a predicted value in a regression

# %%
# Task 12: Finding Z-Score for Outlier Analysis
from scipy.stats import zscore
ipl_auction_df['z_score_price'] = zscore(ipl_auction_df['SOLD PRICE'])

# %%
ipl_auction_df[ (ipl_auction_df.z_score_price > 3.0) | (ipl_auction_df.z_score_price < -3.0) ]
# Outlier would lie in plus or minus 3 SD.
# Out:
#      Sl.NO.    PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 50       51       Kohli, V    1     IND    RCB      Batsman     491       0
# 93       94      Sehwag, V    2     IND     DD      Batsman    8178      40
# 111     112  Tendulkar, SR    3     IND     MI      Batsman   15470      45
# 127     128   Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
#
#      ODI-RUNS-S  ODI-SR-B  ...  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  SR-BL  \
# 50         3590     86.31  ...      49     345     4   86.25   8.84  58.50
# 93         8090    104.68  ...      79     226     6   37.67  10.56  21.67
# 111       18426     86.23  ...      24      58     0    0.00   9.67   0.00
# 127        8051     87.58  ...      67     569    23   24.74   7.02  21.13
#
#      AUCTION YEAR  BASE PRICE  SOLD PRICE  z_score_price
# 50           2011      150000     1800000       3.155606
# 93           2011      400000     1800000       3.155606
# ...

# %%
# Task 13: Drop the rows 
train_X_new = train_X.drop( [50,111,127],axis=0)
train_y_new = train_y.drop( [50,111,127],axis=0)

# %%
# Task 14: Transforming Response Variable
import numpy as np
train_y = np.sqrt( train_y )

# %% [markdown]
# + scikit-learn does not actually have a built-in method for calculating root mean squared error.
# + Since root mean squared error is just the square root of mean squared error,
# + we can use NumPy’s sqrt method to easily calculate it:

# %%
ipl_model_4 = sm.OLS(train_y, train_X).fit()
print(ipl_model_4.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:             SOLD PRICE   R-squared (uncentered):                   0.803
# Model:                            OLS   Adj. R-squared (uncentered):              0.793
# Method:                 Least Squares   F-statistic:                              80.90
# Date:                Fri, 24 Sep 2021   Prob (F-statistic):                    2.14e-33
# Time:                        17:17:21   Log-Likelihood:                         -745.98
# No. Observations:                 104   AIC:                                      1502.
# Df Residuals:                      99   BIC:                                      1515.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
draw_pp_plot( ipl_model_4,"Figure - Normal P-P Plot of Regression Standardized Residuals");

# %% [markdown]
# # Task 15: Making predictions on validation set

# %%
import numpy as np
pred_y = np.power( ipl_model_4.predict( test_X[train_X.columns] ), 2)

# %% [markdown]
# ## Measuring RMSE

# %%
from sklearn import metrics
np.sqrt(metrics.mean_squared_error(pred_y, test_y))
# Out:
# 354557.2605403975

# %% [markdown]
# ## Measuring R-squared value

# %%
np.round( metrics.r2_score(pred_y, test_y), 2 )
# Out:
# 0.57

# %% [markdown]
# + R-squared (R2) is a statistical measure that represents the proportion of the variance for a dependent variable that's explained by an independent variable
