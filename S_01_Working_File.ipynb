# %% [markdown]
# # DNSC 6303_10: PROGRAMMING FOR ANALYTICS - S_01
# ## Introduction to Python
# ### About Python
# + Python is programming language
# + Interpreted, object-oriented, high level language.
# + Java was founded in 1995
# + Python was founded in 1989.
# + Easiest language available in the market.

# %%
from IPython.display import Image
display(Image('img/Picture1.jpg', width=500, unconfined=True))
#Note: in case of error type pip3 install IPython on command prompt

# %% [markdown]
# ## Why Python is popular
# + Python is being used to accomplish many tasks, the most important of which are as follows:
# + Graphical User Interface (GUI) development
# + Scripting web pages
# + Database programming
# + Prototyping
# + Gaming
# + Component based programming

# %% [markdown]
# ## Python …………Name
# + Python is written in C.
# + It was developed by Guido Van Rossum, who is now the Benevolent Director for Life of Python.
# + Disclaimer: Python has got nothing to do with pythons or snakes.
# + The name of the language comes from the show **“Monty Python’s Flying Circus,” ** which was one of the favorite shows of the developer, Guido van Rossum.

# %%
display(Image('img/Picture2.jpg', width=300, unconfined=True))

# %% [markdown]
# # Working directory

# %%
# Check working directory
import os
os.getcwd()


# New 'Cell' or 'Chunk'
# Esc +a +b to add new cells
# Out:
# '/Users/mk/Downloads/S_01_Working Files'

# %%
#library = = = = package 

# Change the current working directory
os.chdir()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-02bb90df2bce> in <module>
#       2
#       3 # Change the current working directory
# ----> 4 os.chdir()
#
# TypeError: chdir() missing required argument 'path' (pos 1)

# %% [markdown]
# ## Lets get familiarize with the python IDE - jupyter notebook

# %%
# Task 1: Print your favorite course name:
# Integrated Development Environment (IDE)
# Different from R - nicely located right below.
print("Hello!")
# Out:
# Hello!

# %%
# Task 2: Please enter your name and age (User input)

name = input("Please enter your name: ")
age = input("Please enter your age: ")
print(name, "you are", age, "years old")
# Out:
# Please enter your name: minhye
# Please enter your age: 32
# minhye you are 32 years old

# %%
# Task 3: Repeat task using function

#function1: w/ argument function2: w/o argument


## def: Python a function is defined using the def keyword
### without argument

def takeinput():
    #w/o argument (empty parenthesis)
    name2 = input("Please enter your name: ")
    age2 = input("Please enter your age: ")
    print(name2, "you are", age2, "years old")
takeinput()
# Out:
# Please enter your name: minhye
# Please enter your age: 32
# minhye you are 32 years old

# %%
takeinput()
# Out:
# Please enter your name: minhye
# Please enter your age: 32
# minhye you are 32 years old

# %%
# Task 4: Write a program to return the minimum of two numbers.
## with argument

def minimum(a,b):
    if a < b:
        return a
    elif b < a:
        return b
    else:
        return "Both the numbers are equal."
    
print(minimum(85, 85))
# Out:
# Both the numbers are equal.

# %%
minimum(6,2)
# Out:
# 2

# %%
minimum(0,-1)
# Out:
# -1

# %%
# Task 5: Write a program to read an integer as string. 
# Convert the string into integer and display the type of value before and after converting to

#default "input" type is string.
num = input("Please enter a number.")
print(num, " and its type is ", type(num))
numint = int(num)
# Out:
# Please enter a number.4
# 4  and its type is  <class 'str'>

# %%
type(numint)
# Out:
# int

# %%
# Task 6: Using loop print first 5 numbers

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Task 7: Using loop pring first 10 number with a gap of 2 digit

for i in range(2, 8, 2):
    print(i)
# Out:
# 2
# 4
# 6

# %%
# Task 8: Check if the number is greater than other a = 63 and b = 56

a = 63
b = 56

if b > a: 
    print("b is greater than a.")

# %%
# Task 9: Debug the error of task 9

if b > a: 
    print("b is greater than a.")
elif a == b: 
    print("a and b are equal.")
else:
    print("a is greater than b.")
# Out:
# a is greater than b.

# %%
# Task 10: Let's play with string. Print first element of "Hello, World!"

a = "Hello, World!"

print(a[0])
# Out:
# H

# %%
# Task 11: Check todays date and time 

import datetime

x = datetime.datetime.now()
str(x.strftime("%Y_%m_%d_%H_%M_%S"))
# Out:
# '2021_09_05_19_42_02'

# %% [markdown]
# ## Lets explore the Async_Material_Folder_01

# %% [markdown]
# ### Simple data types
# + Number (There are three numeric types in Python, int, float, complex)
# + Strings (Strings are represented by the immutable str data type which holds a sequence of Unicode characters.)
# + Boolean (True and False.)

# %%
#Task 12: Let's create a few numbers
# Out:
#   File "<ipython-input-20-baba7a838683>", line 3
#     v1 =
#         ^
# SyntaxError: invalid syntax

# %%
# Task 13: Check out the data types

# %%
# Task 14: Explore string operations using the "Programming for Analytics"
s1= "Programming for Analytics"

# %%
# Task 15: First letter of the string

print(s1[0])
# Out:
# P

# %%
# Task 16: Upper case

print(s1.upper())

print(s1.lower())
# Out:
# PROGRAMMING FOR ANALYTICS
# programming for analytics

# %%
# Task 17: Find the letter position in the string

print(s1.find('mm'))
# Out:
# 6

# %%
# Task 18: Count the letter occurrence 

print(s1.count('a'))
# Out:
# 2

# %%
#Task 19: Replace the letter

s2 = s1.replace('a', 'Z')

print(s2)
# Out:
# ProgrZmming for AnZlytics

# %%
#Task 20: Boolean operations

#True or False

print (10 > 9)
# Out:
# True

# %% [markdown]
# *****************************

# %% [markdown]
# ### Python Compound Data Types
# + lists
# + tuples
# + dictionaries
# + sets

# %% [markdown]
# + List: List is a collection which is ordered and changeable. Allows duplicate members.
# + []: Lists are enclosed in square brackets ( [ and ] )

# %%
# [] is for either List or index

# Task 22: Create a empty list

mylist = []

# %%
# Task 23: Lets add some elements to the list

#the append() method adds an item to the end of the list.

mylist.append("a")

mylist[0]

print(mylist)
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a']

# %%
mylist.append(3)

# %%
mylist
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 3]

# %%
# Task 25: Create a list of your fav movies and Return the name of third, fourth, and fifth movies:

myfavmov = ("Titanic", "La La Land", "Interstellar", "Before Sunrise", "Skyfall")

myfavmov[2:5]
# Out:
# ('Interstellar', 'Before Sunrise', 'Skyfall')

# %% [markdown]
# + Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# + (): In Python tuples are written with round brackets.

# %%
# Task 26: Create a tuple

myTuple = ("34", 33, False, "FALSE", 0.5)

print(myTuple)

# can be different type
# Out:
# ('34', 33, False, 'FALSE', 0.5)

# %%
# Task 27: Access an element

myTuple[3]
# Out:
# 'FALSE'

# %% [markdown]
# ### Task for you post on discussion blog 01
# + Practice Problem: Create a two tuple one for the recommneded shopping site for ' Labor Day sales'
# + and other tuple suggesting 'Labor Day sales'
# + combine both tuples

# %%
myTuple1 = ("rei.com", "costco.com", "athleta.gap.com")
myTuple2 = ("Labor Day Clearance", "Same-Day Delivery", "Summer Send-Off")

combinedTuple = myTuple1 + myTuple2
print(combinedTuple)
# Out:
# ('rei.com', 'costco.com', 'athleta.gap.com', 'Labor Day Clearance', 'Same-Day Delivery', 'Summer Send-Off')

# %% [markdown]
# + Dictionaries: A dictionary is a collection which is unordered, changeable and indexed.
# + {}: written with curly brackets, and they have keys and values.

# %%
# Task 28:Create a dictionary of Assignments Score
myAsgn = {"A1":100, "A2":101, "A3":102, "A4":103, "A5":104} #Key & Index

#Hinderline: autocomplete codes -- to be installed

# %%
# Task 29: Access dictionary value using key
myAsgn["A1"]
# Out:
# 100

# %%
# Task 30: Length of dictionary
len(myAsgn)
# Out:
# 5

# %% [markdown]
# + set: A set is a collection which is unordered and unindexed.
# + {}: sets are written with curly brackets.

# %%
# Task 31: Create two sets
set1 = {1,2,3}
set2 = {2,3,4}

# %%
# Task 32: union: the union of a collection of sets is the set of all elements in the collection. I
set1.union(set2)
# Out:
# {1, 2, 3, 4}

# %%
# Task 33: intersection: The set operation intersection takes only the elements that are in both set
set1.intersection(set2)
# Out:
# {2, 3}

# %%
# Task 34: difference: The difference of set B from set A, denoted by A-B, is the set of all the elements of set A that are not in set B. 
set2.difference(set1)
# Out:
# {4}

# %%
set1.difference(set2)
# Out:
# {1}

# %%
set2 - set1 # tip from another student
# Out:
# {4}

# %% [markdown]
# ### Task for you post on discussion blog 01
# + Practice Problem: create two sets
# + set1 contains string type of data
# + set 1 contains numeric type of data
# + Explore the union, intersection and difference operations

# %%
mySet1 = {"a", "b", "c"}
mySet2 = {0, 1, 2}

mySet1.union(mySet2)
# Out:
# {0, 1, 2, 'a', 'b', 'c'}

# %%
mySet1.intersection(mySet2)
# Out:
# set()

# %%
mySet1.difference(mySet2)
# Out:
# {'a', 'b', 'c'}

# %% [markdown]
# ***************************************

# %% [markdown]
# ## Handling of files

# %% [markdown]
# #### Reading csv files using pandas

# %%
# Task 35: Read Employee data.csv files using pandas
import pandas as pd

df = pd.read_csv("Employee data.csv")

df
# Out:
#       id gender        bdate  educ  jobcat   salary salbegin  jobtime  \
# 0      1      m   3-Feb-1952    15       3  $57,000  $27,000       98
# 1      2      m  23-May-1958    16       1  $40,200  $18,750       98
# 2      3      f  26-Jul-1929    12       1  $21,450  $12,000       98
# 3      4      f  15-Apr-1947     8       1  $21,900  $13,200       98
# 4      5      m   9-Feb-1955    15       1  $45,000  $21,000       98
# ..   ...    ...          ...   ...     ...      ...      ...      ...
# 469  470      m  22-Jan-1964    12       1  $26,250  $15,750       64
# 470  471      m   3-Aug-1966    15       1  $26,400  $15,750       64
# 471  472      m  21-Feb-1966    15       1  $39,150  $15,750       63
# 472  473      f  25-Nov-1937    12       1  $21,450  $12,750       63
# 473  474      f   5-Nov-1968    12       1  $29,400  $14,250       63
#
#      prevexp  minority
# 0        144         0
# 1         36         0
# 2        381         0
# 3        190         0
# 4        138         0
# ..       ...       ...
# 469       69         1
# 470       32         1
# 471       46         0
# 472      139         0
# 473        9         0
#
# [474 rows x 10 columns]

# %%
# Task 36: Read wine.csv files using pandas and print first 5 rows

winedf = pd.read_csv("wine.csv")
head(winedf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-ba7b96381212> in <module>
#       2
#       3 winedf = pd.read_csv("wine.csv")
# ----> 4 head(winedf)
#
# NameError: name 'head' is not defined

# %% [markdown]
# #### Reading text file using pandas

# %% [markdown]
# + UTF-8 is a byte oriented encoding. The encoding specifies that each character is represented by a specific sequence of one or more bytes
# + if anyone getting 'utf - 8' , fh = open("frost.txt", "rb")
# + Files typically reside in non-volatile memory
# + Require a file handle
# + A handle is an abstract reference to a computing resource. Handles are used when application software references a resource - in our case, a file.

# %%
# Task 37: Read the 'frost.txt'

# Amazon reviews

# filehandler 

fh = open("frost.txt", 'rb') #read mode #'r' for windows # 'rb' for mac (binary)


fhread = fh.read()

print(fhread)
# Out:
# b'Stopping by Woods on a Snowy Evening\r\nBY ROBERT FROST\r\n\r\nWhose woods these are I think I know.   \r\nHis house is in the village though;   \r\nHe will not see me stopping here   \r\nTo watch his woods fill up with snow.   \r\n\r\nMy little horse must think it queer   \r\nTo stop without a farmhouse near   \r\nBetween the woods and frozen lake   \r\nThe darkest evening of the year.   \r\n\r\nHe gives his harness bells a shake   \r\nTo ask if there is some mistake.   \r\nThe only other sound\x92s the sweep   \r\nOf easy wind and downy flake.   \r\n\r\nThe woods are lovely, dark and deep,   \r\nBut I have promises to keep,   \r\nAnd miles to go before I sleep,   \r\nAnd miles to go before I sleep.'

# %%
#don't forget to close or it will affect the original file

fh.close()

# %% [markdown]
# ## Lets Practice some Simple programs in Python

# %%
# Task 38: This is readline for python

# %%
# Task 39: if and else

# %%
# Task 40: Write a program to read string and display ‘Total number of uppercase and lowercase letters’.

# %% [markdown]
# ### Task for you post on discussion blog 01
# + Practice Problem: Refer our DNSC 6303_10 syllabus and Print the grading scale using conditional statements.
