# %% [markdown]
# # DNSC 6303 - 10: PROGRAMMING FOR ANALYTICS - SS_03
#
# ### Class Note: inclass practic Numpy and Pandas and lets explore Data Visualization using Matplotlib

# %%
# Task 1: Read multiple files using glob 
import glob
import pandas as pd

mydata = pd.DataFrame()
path = "data folder/*.csv"
for fname in glob.glob(path):
    df = pd.read_csv(fname)
    mydata = mydata.append(df, ignore_index = True)

# the glob module is used to retrieve files/pathnames matching a specified pattern. 

mydata
# Out:
#     Name  Age
# 0  Larry   20
# 1    Moe   45
# 2  Curly   32
# 3    Tom   87
# 4   Dick   54
# 5  Harry   21
# 6  Sally   29
# 7   Mary   45
# 8    Liz   32

# %%
# Task 2: Save the output file

filenames = ['File1.txt', 'File2.txt']

with open('outfile.txt', 'w') as outfile:
     for fname in filenames:
            with open (fname) as infile:
                for line in infile:
                    outfile.write(line)


# To merge multiple files in a new file, you can simply read files and write them to a new file using loops.

# %% [markdown]
# # Inclass Practice

# %%
# Task 3: Read files "athlete_events.csv" and "noc_regions.csv"
# Create bar plot for top 25 sport counts 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline 

# It is a magic function that renders the figure in a notebook

# %%
df1 = pd.read_csv("athlete_events.csv")
df2 = pd.read_csv("noc_regions.csv")

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df2
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
# + Column or index level names to join on. These must be found in both DataFrames.
# + If on is None and not merging on indexes then this defaults to the intersection of the columns in both DataFrames.

# %%
df3 = pd.merge(df1, df2, on = 'NOC', how = 'left')

# %%
df3
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df3.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df3.info() # Dtype(object) is for string cells
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %% [markdown]
# + Selecting data by row numbers (.iloc);
# + Selecting data by label or by a conditional statment (.loc)
# + ~  is a complement operator (invert)
# + isnull() function detect missing values in the given series object

# %%
medalists_df = df3.loc[~df3['Medal'].isnull()]

# %%
medalists_df
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %% [markdown]
# + **value_counts():** method returns a Series containing the counts of unique values. This means, for any column in a dataframe, this method returns the count
# + **nlargest(25):** Return the first 25 rows ordered by columns in descending(largest to the smallest) order.
# + **to_frame():** to_frame() function create a dataFrame from the given index with a column containing the Index

# %%
sports_count = medalists_df['Sport'].value_counts().nlargest(25).to_frame()

# %%
sports_count
# Out:
#                       Sport
# Athletics              3969
# Swimming               3048
# Rowing                 2945
# Gymnastics             2256
# Fencing                1743
# Football               1571
# Ice Hockey             1530
# Hockey                 1528
# Wrestling              1296
# Cycling                1263
# Sailing                1232
# Shooting               1228
# Canoeing               1165
# Basketball             1080
# Handball               1060
# Water Polo             1057
# Volleyball              969
# Equestrianism           965
# Boxing                  944
# Cross Country Skiing    776
# Weightlifting           646
# Speed Skating           580
# Judo                    547
# Alpine Skiing           428
# Diving                  427

# %%
ax = sports_count.plot.bar(y = 'Sport')
ax.legend_.remove()

# %% [markdown]
# + get_legend():function in axes module of matplotlib library is used to return the Legend instance, or None if no legend is defined.
# + remove(): method removes the first matching element (which is passed as an argument) from the list.

# %% [markdown]
# # Some example from Async_Material_03

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

url="https://stats.idre.ucla.edu/stat/data/hsbdemo.dta"
df=pd.read_stata(url)

# %%
df.head()
# Out:
#       id  female     ses  schtyp      prog  read  write  math  science  socst  \
# 0   45.0  female     low  public  vocation  34.0   35.0  41.0     29.0   26.0
# 1  108.0    male  middle  public   general  34.0   33.0  41.0     36.0   36.0
# 2   15.0    male    high  public  vocation  39.0   39.0  44.0     26.0   42.0
# 3   67.0    male     low  public  vocation  37.0   37.0  42.0     33.0   32.0
# 4  153.0    male  middle  public  vocation  39.0   31.0  40.0     39.0   51.0
#
#          honors  awards  cid
# 0  not enrolled     0.0    1
# 1  not enrolled     0.0    1
# 2  not enrolled     0.0    1
# 3  not enrolled     0.0    1
# 4  not enrolled     0.0    1

# %%
#Task4: Plot the bar plot based on social economic status (ses)
fig, ax = plt.subplots()
df['ses'].value_counts().plot(ax=ax, kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# + plt.subplots() is a function that returns a tuple containing a figure and axes object(s).
# + Thus when using fig, ax = plt.subplots() you unpack this tuple into the variables fig and ax
# + subplots():The function returns a figure object and a tuple containing axes objects equal to nrows*ncols.
# + value_counts(): method returns a Series containing the counts of unique values.

# %%
#Task5: Create a histogram for 'read' variable  
df.hist(column = 'read')
# Out:
# array([[<AxesSubplot:title={'center':'read'}>]], dtype=object)

# %%
#Task6: Create a scatter plot between 'read' and 'math'
df.plot.scatter(x = 'read', y = 'math')
# Out:
# <AxesSubplot:xlabel='read', ylabel='math'>

# %% [markdown]
# + n: is the number of counts in each bin of the histogram
# + bins: is the left hand edge of each bin
# + patches is the individual patches used to create the histogram, e.g a collection of rectangles
# + bins : integer or array_like, optional, default: 10
# + density=1/True: If True, draw and return a probability density: each bin will display the bin's raw count divided by the total number of counts and the bin width (density = counts / (sum(counts) * np.diff(bins))), so that the area under the histogram integrates to 1
# + alpha=0.75: specify transparency levels for the fill color with alpha=0.75
# + r means the string will be treated as raw string.

# %%
# Task7: Create a histogram for random number with mu = 100, and sigma = 15
mu, sigma = 100, 15 # mean and sd
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density = True, color = 'r', alpha = 0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$') # add Greek letters # regular expressions
plt.axis([40, 150, 0, 0.03])
plt.grid(True)

# %%
### Case Study: Covid-19

# %%
from IPython.display import Image
Image("img/pic1.png",width=500, height=500)

# %%
# Required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Task 8: Read the 'covid.csv' file and check the data 
covid = pd.read_csv('covid.csv')
covid.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-05-26 02:32:35
# 1  22001.0     Acadia       Louisiana             US  2020-05-26 02:32:35
# 2  51001.0   Accomack        Virginia             US  2020-05-26 02:32:35
# 3  16001.0        Ada           Idaho             US  2020-05-26 02:32:35
# 4  19001.0      Adair            Iowa             US  2020-05-26 02:32:35
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707         35       0          0      35
# 1  30.295065  -92.414197        299      18          0     281
# 2  37.767072  -75.632346        731      11          0     720
# 3  43.452658 -116.241552        796      23          0     773
# 4  41.330756  -94.471059          8       0          0       8
#
#                     Combined_Key
# 0  Abbeville, South Carolina, US
# 1          Acadia, Louisiana, US
# 2         Accomack, Virginia, US
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3414 entries, 0 to 3413
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FIPS            3008 non-null   float64
#  1   Admin2          3011 non-null   object
#  2   Province_State  3236 non-null   object
#  3   Country_Region  3414 non-null   object
#  4   Last_Update     3414 non-null   object
#  5   Lat             3345 non-null   float64
#  6   Long_           3345 non-null   float64
#  7   Confirmed       3414 non-null   int64
#  8   Deaths          3414 non-null   int64
#  9   Recovered       3414 non-null   int64
#  10  Active          3414 non-null   int64
#  11  Combined_Key    3414 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 320.2+ KB

# %% [markdown]
# + sum() function adds start and items of the given iterable from left to right.

# %%
# Task 9: Check for 'null values'
## isnull() function detect missing values in the given series object. 
covid.isnull().sum()
# Out:
# FIPS              406
# Admin2            403
# Province_State    178
# Country_Region      0
# Last_Update         0
# Lat                69
# Long_              69
# Confirmed           0
# Deaths              0
# Recovered           0
# Active              0
# Combined_Key        0
# dtype: int64

# %%
# Task 10: Drop the 'null values'
## The dropna() function is used to remove missing values.
## ‘any’ : If any NA values are present, drop that row or column.
## ‘all’ : If all values are NA, drop that row or column.

# create a new dataframe

covid1 = covid.dropna()

# %%
covid1
# Out:
#          FIPS        Admin2  Province_State Country_Region  \
# 0     45001.0     Abbeville  South Carolina             US
# 1     22001.0        Acadia       Louisiana             US
# 2     51001.0      Accomack        Virginia             US
# 3     16001.0           Ada           Idaho             US
# 4     19001.0         Adair            Iowa             US
# ...       ...           ...             ...            ...
# 3006  48505.0        Zapata           Texas             US
# 3007  48507.0        Zavala           Texas             US
# 3008  46137.0       Ziebach    South Dakota             US
# 3412   2066.0  Copper River          Alaska             US
# 3413   2063.0       Chugach          Alaska             US
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 0     2020-05-26 02:32:35  34.223334  -82.461707         35       0
# 1     2020-05-26 02:32:35  30.295065  -92.414197        299      18
# ...

# %%
# Task 11: Check change for 'null values'
covid1.isnull().sum()
# Out:
# FIPS              0
# Admin2            0
# Province_State    0
# Country_Region    0
# Last_Update       0
# Lat               0
# Long_             0
# Confirmed         0
# Deaths            0
# Recovered         0
# Active            0
# Combined_Key      0
# dtype: int64

# %% [markdown]
# + Removing superfluous columns like ‘FIPS’, ‘Admin2', ‘Last_Update’ (since all the data is for single-day — 25th May).
# + Removing columns ‘Province_State’ and ‘Combined_Key’ since statewide data is not available for all the countries.
# + Grouping together data by ‘Country_Region’ and rename the column to ‘Country’

# %%
# Task 12: Remove all superfluous columns, rename 
covid.drop(['FIPS', 'Admin2', 'Last_Update', 'Province_State', 'Combined_Key'], axis = 1, inplace = True)
covid.rename(columns = {'Country_Region': 'Country'}, inplace = True)

# %% [markdown]
# + axis=1 axis :0 or 'index', 1 or 'columns', if you specify axis=1 you will be removing columns.
# + When inplace = True , the data is modified in place, which means it will return nothing and the dataframe is now updated.
# + When inplace = False , which is the default, then the operation is performed and it returns a copy of the object.

# %%
covid
# Out:
#        Country        Lat       Long_  Confirmed  Deaths  Recovered  Active
# 0           US  34.223334  -82.461707         35       0          0      35
# 1           US  30.295065  -92.414197        299      18          0     281
# 2           US  37.767072  -75.632346        731      11          0     720
# 3           US  43.452658 -116.241552        796      23          0     773
# 4           US  41.330756  -94.471059          8       0          0       8
# ...        ...        ...         ...        ...     ...        ...     ...
# 3409     Yemen  15.552727   48.516388        233      44         10     179
# 3410    Zambia -13.133897   27.849332        920       7        336     577
# 3411  Zimbabwe -19.015438   29.154857         56       4         25      27
# 3412        US  60.388600 -162.890520          0       0          0       0
# 3413        US  61.166660 -149.900000          2       0          0       0
#
# [3414 rows x 7 columns]

# %%
# Task 13: Group the 'country' by 'Confirmed','Active','Recovered','Deaths'
world = covid.groupby('Country')['Confirmed','Active','Recovered','Deaths'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-e4edc63946cc> in <module>
#       1 # Task 13: Group the 'country' by 'Confirmed','Active','Recovered','Deaths'
# ----> 2 world = covid.groupby('Country_Region')['Confirmed','Active','Recovered','Deaths'].sum().reset_index()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
world
# Out:
#                 Country  Confirmed  Active  Recovered  Deaths
# 0           Afghanistan      11176    9857       1097     220
# 1               Albania       1004     177        795      32
# 2               Algeria       8503    3147       4747     609
# 3               Andorra        763      49        663      51
# 4                Angola         70      48         18       4
# ..                  ...        ...     ...        ...     ...
# 183             Vietnam        326      54        272       0
# 184  West Bank and Gaza        423      63        357       3
# 185               Yemen        233     179         10      44
# 186              Zambia        920     577        336       7
# 187            Zimbabwe         56      27         25       4
#
# [188 rows x 5 columns]

# %% [markdown]
# + sum() function returns a number, the sum of all items in an iterable.
# + reset_index(): is a method to reset index of a Data Frame.
# + reset_index() method sets a list of integer ranging from 0 to length of data as index.

# %%
# Experimentation data 
world1 = covid1.groupby('Country_Region')['Confirmed','Active','Recovered','Deaths'].sum().reset_index()

# %%
world1
# Out:
#   Country_Region  Confirmed   Active  Recovered  Deaths
# 0             US    1646708  1548513          0   97804

# %%
# Task 14: Find top 20 countries with maximum number of confirmed cases
top_20 = world.sort_values(by = ['Confirmed'], ascending = False).head(20)
top_20
# Out:
#             Country  Confirmed   Active  Recovered  Deaths
# 175              US    1663578  1218472     379157   98601
# 23           Brazil     374898   197592     153833   23473
# 140          Russia     353427   230996     118798    3633
# 179  United Kingdom     262547   224390       1161   36996
# 159           Spain     235400    58190     150376   26834
# 85            Italy     230158    55300     141981   32877
# 62           France     184585    89290      65317   28461
# 66          Germany     180600    11092     161199    8309
# 174          Turkey     157814    33430     120015    4369
# 79            India     144950    80072      60706    4172
# 81             Iran     137724    22560     107713    7451
# 134            Peru     123979    69401      50949    3629
# 32           Canada      87119    35813      44651    7420
# 36            China      84102      112      79352    4638
# 148    Saudi Arabia      74795    28728      45668     399
# ...

# %%
plt.figure(figsize = (12, 10))
_ = sns.barplot(top_20['Confirmed'], top_20['Country'])

# %%
# Task 15: Explore enumerate and zip function

# %%
from IPython.display import Image
Image("img/pic2.gif",width=500, height=500)

# %% [markdown]
# + enumerate() in Python: Get the element and index from a list
# + zip() in Python: Get elements from multiple lists
# + You can get the index with enumerate(), and get the elements of multiple iterables with zip()
# + syntax: for i, (a, b, ...) in enumerate(zip( ... ))

# %%
# Task 16: Add labels on the bar plot
plt.figure(figsize=(12,10))
plot = sns.barplot(top_20['Confirmed'],top_20['Country'])
for i,(value,name) in enumerate(zip(top_20['Confirmed'],top_20['Country'])):
    plot.text(value,i-0.05,f'{value:,.0f}', size = 12)
plt.show()

# %% [markdown]
# ### Task 17-19: Task for BB Week_3 Blog Find top 20 countries with maximum number of Active cases, Recovered cases and  Deaths cases

# %% [markdown]
# ### How to access inbuilt dataset in python
# + **Click the Link below for the List of datasets:**
#     + [Link](https://vincentarelbundock.github.io/Rdatasets/datasets.html)

# %% [markdown]
# + statsmodels is a Python package that provides a complement to scipy for statistical computations including descriptive statistics and estimation and inference for statistical models.
# + api (application programming interface): The API focuses on models and the most frequently used statistical test, and tools.

# %%
# Task 20: Import the 'iris' dataset
import statsmodels.api as sm
#from statsmodels.datasets import iris
iris = sm.datasets.get_rdataset('iris','datasets')
iris.data

# %%
print(iris.__doc__)

# %% [markdown]
# # Role of analytics in show business

# %%
from IPython.display import Image
# Task 21: Read the file "script01.txt" and count the number of character 
# aniticipated outcome:
Image("img/pic3.jpg",width=800, height=800)
